# %%
# Author: Partha Deka
# Version: 1.0
# Date: 2024-03-03

# %% [markdown]
# ### Chapter 7
# ### Fearture Engineering with the Housing Price Dataset
# This notebook is a companion to the book XGBoost for Regression Predictive Modeling and Time Series Analysis. This chapter is a hands on guide for feature enineering designed to give you experience with exploratory data anslysis and different feature engineering techniques
#
# ### Citing some the sources I took some inspiration from
#
# - [Comprehensive data exploration with Python](https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python) - Kaggle kernel
# - [kaggle Houysing price prediction](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/) - Kaggle kernel
# - [Deploying Machine Learnin models](https://intel.udemy.com/organization/search/?src=ukw&q=Deploying+machine+learning+models) - Online Course

# %% [markdown]
# ### Feature Engineering with the housing Price dataset
#
# The house price data is available here -[housing_price_data](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data)
#
# #### Citation for this dataset: `Dean De Cock(2011) Ames, Iowa: Alternative to the Boston Housing Data as an End of Semester Regression Project, Journal of Statistics Education, 19:3, DOI: 10.1080/10691898.2011.11889627. `
#
# - importing dependencies
# - loading the data into `pandas`

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import joblib

pd.pandas.set_option("display.max_columns", None)

# %%
# load dataset
data = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/XGBoost-for-Regression-Predictive-Modeling-and-Time-Series-Analysis/df08c61bc022cd5b61115f116946c90e6835ee95/ch7/house_pricing.csv')
print(data.shape)
data.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %% [markdown]
# # First & Foremost: `Separate dataset into train and test`
#
# It is critical to separate our data intro training and testing set at the beginning. While engineering features some of the techniques learn the parameters from the data, its import to learn the parameters from the train set only, if we learn from the whole dataset then we are leaking informastion from the train dataset to the test
#
# Some of the feature engineering techniques we will learn from the train set are below
#
# - mean
# - mode
# - category frequency
# - and category to number mappings

# %%
# Separating the dataset into train and test set, we will keep a randomseed so that we can reproduce the exact same train test set

# data.drop(["Id", "SalePrice"] --> Variables to predict the target
# data["SalePrice"]  ---> target
# test_size=0.1 --> percetange data allocate for Test
# random_state=0  --> randomseed for reproducing the train and test dataset

X_train, X_test, y_train, y_test = train_test_split(data.drop(["Id", "SalePrice"], axis=1), data["SalePrice"], test_size=0.1, random_state=0)

X_train.shape, X_test.shape
# Out:
# ((1314, 79), (146, 79))

# %% [markdown]
# # Performing feature Engineering
#
# Some of the feature engineering techinques dicussed below will handle the following :
#
# - Missing values
# - Temporal variables
# - putting variables in `similar scale`

# %% [markdown]
# ## Handling `Missing values` for `categorical variables`
#
# We will perform the following steps
# - Replace missing variable with the string "missing" for those variables with a lot of missing data
# - Replace missing values with the most frequent category for those variables with few missing observations

# %%
# identifying the catagorical variables

vars_cat = [var for var in data.columns if data[var].dtype == "O"]

# We will add the variable MSSubClass to the list of catagorical variables. Please find the definition of
# variable in the data_description.txt available in the kaggle website (https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data?select=data_description.txt)


# MSSubClass: Identifies the type of dwelling involved in the sale.

#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES


vars_cat = vars_cat + ["MSSubClass"]

# casting all categorical variables as object type
X_train[vars_cat] = X_train[vars_cat].astype("O")
X_test[vars_cat] = X_test[vars_cat].astype("O")

# number of categorical variables
len(vars_cat)
# Out:
# 44

# %%
#categorical variables that contain missing values

cat_vars_with_na = [var for var in vars_cat if X_train[var].isnull().sum() > 0]

# percentage of missing for each of these variables
X_train[cat_vars_with_na ].isnull().mean().sort_values(ascending=False)
# Out:
# PoolQC          0.995434
# MiscFeature     0.961187
# Alley           0.938356
# Fence           0.814307
# MasVnrType      0.601218
# FireplaceQu     0.472603
# GarageFinish    0.056317
# GarageQual      0.056317
# GarageType      0.056317
# GarageCond      0.056317
# BsmtExposure    0.025114
# BsmtFinType2    0.025114
# BsmtQual        0.024353
# BsmtFinType1    0.024353
# BsmtCond        0.024353
# Electrical      0.000761
# dtype: float64

# %%
# variables with missing value to replace with string missing -- we are keeping 10 % as the threshold
for_missing_string = [var for var in cat_vars_with_na if X_train[var].isnull().mean() > 0.1]

# %%
print(for_missing_string)
# Out:
# ['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
# replace missing values with 'missing' string

X_train[for_missing_string] = X_train[for_missing_string].fillna('Missing')
X_test[for_missing_string] = X_test[for_missing_string].fillna('Missing')

# %%
# variables with missing values to replace with the most frequent category  -- we are keeping 10 % as the threshold
for_frequent_category = [var for var in cat_vars_with_na if X_train[var].isnull().mean() < 0.1]

# %%
# replace missing values with the most frequent category

for var in for_frequent_category:

    # take the most common one, there can multiples of them, we take the first one
    mode = X_train[var].mode()[0]

    print(var, mode)

    X_train[var].fillna(mode, inplace=True)
    X_test[var].fillna(mode, inplace=True)
# Out:
# Alley Missing
# MasVnrType Missing
# BsmtQual TA
# BsmtCond TA
# BsmtExposure No
# BsmtFinType1 Unf
# BsmtFinType2 Unf
# Electrical SBrkr
# FireplaceQu Missing
# GarageType Attchd
# GarageFinish Unf
# GarageQual TA
# GarageCond TA
# PoolQC Missing
# Fence Missing
# MiscFeature Missing
# /tmp/ipython-input-3930982505.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[var].fillna(mode, inplace=True)
# /tmp/ipython-input-3930982505.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test[var].fillna(mode, inplace=True)

# %%
# Lets check there is no missing or null values in these engineered features or variables in the train set

X_train[cat_vars_with_na].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
# Lets check there is no missing or null values in these engineered features or variables in the test set

X_test[cat_vars_with_na].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %% [markdown]
# ## Handling `Missing values` for `numerical variables`
#
# - first, creating a new binary indicator variable
# - second, replacing missing values with the mean value in the original variables

# %%
# now let's identify the numerical variables

vars_num = [var for var in X_train.columns if var not in vars_cat and var != "SalePrice"]

# number of numerical variables
len(vars_num)
# Out:
# 35

# %%
# the numerical variables that contain missing values
vars_num_na = [var for var in vars_num if X_train[var].isnull().sum() > 0]

# percentage of missing values per variable
X_train[vars_num_na ].isnull().mean()
# Out:
# LotFrontage    0.177321
# MasVnrArea     0.004566
# GarageYrBlt    0.056317
# dtype: float64

# %%
# creating binary variables and replacing null value with mean as described above

for var in vars_num_na:

    # calculate the mean value for each varible from the train set
    mean_val = X_train[var].mean()

    # creating binary indicator variable for both  train and test set
    X_train[var + "_na"] = np.where(X_train[var].isnull(), 1, 0)
    X_test[var + "_na"] = np.where(X_test[var].isnull(), 1, 0)

    # replace missing values in the train and test set with train mean value
    X_train[var].fillna(mean_val, inplace=True)
    X_test[var].fillna(mean_val, inplace=True)
# Out:
# /tmp/ipython-input-3486401139.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[var].fillna(mean_val, inplace=True)
# /tmp/ipython-input-3486401139.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test[var].fillna(mean_val, inplace=True)
# /tmp/ipython-input-3486401139.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[var].fillna(mean_val, inplace=True)
# /tmp/ipython-input-3486401139.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test[var].fillna(mean_val, inplace=True)
# /tmp/ipython-input-3486401139.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[var].fillna(mean_val, inplace=True)
# /tmp/ipython-input-3486401139.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test[var].fillna(mean_val, inplace=True)

# %%
# check if we have missing values any more in train set
X_train[vars_num_na].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
# check if we have missing values any more in test set
X_test[vars_num_na].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
# lets check the binary indicator variables

X_train[["LotFrontage_na", "MasVnrArea_na", "GarageYrBlt_na"]].head()
# Out:
#       LotFrontage_na  MasVnrArea_na  GarageYrBlt_na
# 930                0              0               0
# 656                0              0               0
# 45                 0              0               0
# 1348               1              0               0
# 55                 0              0               0

# %% [markdown]
# ## Handling `numerical varibles with some transformations`
#
# ### Performing `Log transform`
#
# We will perform log transformstion on the postive numerical variables for which the distribution is not normal( https://github.com/PacktPublishing/XGBoost-for-Regression-Predictive-Modeling-and-Time-Series-Analysis/blob/partha1/ch7/exploratory_data_analysis.ipynb)
#
# This will tranform these variables to be more Gaussian-like distribution. Please refer the data description to learn more on these variables - https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data?select=data_description.txt

# %%
import matplotlib.pyplot as plt

# %%
var_for_log_trans = ["LotFrontage", "1stFlrSF", "GrLivArea","LotArea"]
plotdf = X_train [var_for_log_trans]
fig, axes = plt.subplots(1,4, figsize=(16,4))
axes_flat = axes.flatten()

for i, (column, ax) in enumerate(zip(plotdf.columns, axes_flat)):
    plotdf[column].plot.hist(ax=ax, bins= 15, alpha = 0.5, color = "grey", edgecolor = "black")
    ax.set_title(f"Histogram of {column}", fontsize = 10)
    ax.set_xlabel(column, fontsize = 10)
    ax.set_ylim(0, 1300)

plt.tight_layout()
plt.show()

# %%
for var in var_for_log_trans:
    X_train["log_"+ var] = np.log(X_train[var])
    X_test["log_" + var] = np.log(X_test[var])

# %%
log_trans = ["log_LotFrontage", "log_1stFlrSF", "log_GrLivArea","log_LotArea"]
plotdf = X_train [log_trans]
fig, axes = plt.subplots(1,4, figsize=(16,4))
axes_flat = axes.flatten()

for i, (column, ax) in enumerate(zip(plotdf.columns, axes_flat)):
    plotdf[column].plot.hist(ax=ax, bins= 15, alpha = 0.5, color = "grey", edgecolor = "black")
    ax.set_title(f"Histogram of {column}", fontsize = 10)
    ax.set_xlabel(column, fontsize = 10)
    ax.set_ylim(0, 1300)

plt.tight_layout()
plt.show()

# %%
# check for missing values in these transformed variables in train set
X_train[log_trans].isnull().sum()
# Out:
# log_LotFrontage    0
# log_1stFlrSF       0
# log_GrLivArea      0
# log_LotArea        0
# dtype: int64

# %%
# check for missing values in these transformed variables in test set
X_test[log_trans].isnull().sum()
# Out:
# log_LotFrontage    0
# log_1stFlrSF       0
# log_GrLivArea      0
# log_LotArea        0
# dtype: int64

# %% [markdown]
# ## Apply Log scale on Target

# %%
y_train_log = np.log(y_train)
y_test_log = np.log(y_test)

# %% [markdown]
# ### Handling `skewed variables by transforming into binary variables`
#
# As dicussed in the exploratory data analysis notebook, we will transform the skewed variables into binary variables.

# %%
skewed_vars = ['ScreenPorch', 'EnclosedPorch']
plotdf = X_train [skewed_vars]
fig, axes = plt.subplots(1,2, figsize=(16,4))
axes_flat = axes.flatten()

for i, (column, ax) in enumerate(zip(plotdf.columns, axes_flat)):
    plotdf[column].plot.hist(ax=ax, bins= 15, alpha = 0.5, color = "grey", edgecolor = "black")
    ax.set_title(f"Histogram of {column}", fontsize = 10)
    ax.set_xlabel(column, fontsize = 10)
    ax.set_ylim(0, 1300)

plt.tight_layout()
plt.show()

# %%
for var in skewed_vars:
    # map the variable values into 0 and 1
    X_train["binary_"+ var] = np.where(X_train[var]==0, 0, 1)
    X_test["binary_"+ var] = np.where(X_test[var]==0, 0, 1)

# %%
binary_trans = ["binary_ScreenPorch", "binary_EnclosedPorch"]
plotdf = X_train [binary_trans]
fig, axes = plt.subplots(1,2, figsize=(16,4))
axes_flat = axes.flatten()

for i, (column, ax) in enumerate(zip(plotdf.columns, axes_flat)):
    plotdf[column].plot.hist(ax=ax, bins= 15, alpha = 0.5, color = "grey", edgecolor = "black")
    ax.set_title(f"Histogram of {column}", fontsize = 10)
    ax.set_xlabel(column, fontsize = 10)
    ax.set_ylim(0, 1300)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scaling features
#
# For most linear machine learning models (except decision tree based models) we need to scale features. Here we will perform min max scaling.
# Please read about Min max scaler here if you are not already familiar with it - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html

# %%
# work with the numberic columns only
X_train_num = X_train[vars_num]
X_train_num.head()
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 930     73.000000     8925            8            5       2007          2007
# 656     72.000000    10007            5            7       1959          2006
# 45      61.000000     7658            9            5       2005          2005
# 1348    69.879741    16196            7            5       1998          1998
# 55     100.000000    10175            6            5       1964          1964
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 930          0.0          16           0       1450         1466      1466
# 656         54.0         806           0        247         1053      1053
# 45         412.0         456           0       1296         1752      1752
# 1348         0.0        1443           0         39         1482      1494
# 55         272.0         490           0        935         1425      1425
#
#       2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# 930          0             0       1466             0             0         2
# 656          0             0       1053             1             0         1
# 45           0             0       1752             1             0         2
# 1348         0             0       1494             1             0         2
# 55           0             0       1425             0             0         2
#
#       HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 930          0             3             1             7           0
# 656          1             3             1             5           0
# 45           0             2             1             6           1
# 1348         0             3             1             5           1
# 55           0             3             1             7           1
#
#       GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 930        2007.0           3         610         100           18
# 656        1959.0           1         312           0            0
# 45         2005.0           2         576         196           82
# 1348       1998.0           2         514         402           25
# 55         1964.0           2         576           0            0
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold
# 930               0          0            0         0        0       7    2009
# 656               0          0            0         0        0       8    2008
# 45                0          0            0         0        0       2    2010
# 1348              0          0            0         0        0       8    2007
# 55                0        407            0         0        0       7    2008

# %%
X_test_num = X_test[vars_num]
X_test_num.head()
# Out:
#      LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 529    69.879741    32668            6            3       1957          1975
# 491    79.000000     9490            6            7       1941          1950
# 459    69.879741     7015            5            4       1950          1950
# 279    83.000000    10005            7            5       1977          1977
# 655    21.000000     1680            6            5       1971          1971
#
#      MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 529  103.797401        1219           0        816         2035      2515
# 491    0.000000         403         165        238          806       958
# 459  161.000000         185           0        524          709       979
# 279  299.000000         392           0        768         1160      1156
# 655  381.000000           0           0        525          525       525
#
#      2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# 529         0             0       2515             1             0         3
# 491       620             0       1578             1             0         1
# 459       224             0       1203             1             0         1
# 279       866             0       2022             0             0         2
# 655       567             0       1092             0             0         1
#
#      HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 529         0             4             2             9           2
# 491         0             3             1             5           2
# 459         0             3             1             5           1
# 279         1             4             1             8           1
# 655         1             3             1             6           0
#
#      GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 529       1975.0           2         484           0            0
# 491       1941.0           1         240           0            0
# 459       1950.0           1         352           0            0
# 279       1977.0           2         505         288          117
# 655       1971.0           1         264           0            0
#
#      EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold
# 529            200          0            0         0        0       3    2007
# 491             32          0            0         0        0       8    2006
# 459            248          0            0         0        0       7    2009
# 279              0          0            0         0        0       3    2008
# 655              0          0            0         0        0       3    2010

# %%
# set the scale from the sklearn library import at the beginning of this notebook
from sklearn.preprocessing import MinMaxScaler

set_scale = MinMaxScaler()

# %%
# fit it on the train dataset
scaler = set_scale.fit(X_train_num.values)

# %%
X_train_num
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 930     73.000000     8925            8            5       2007          2007
# 656     72.000000    10007            5            7       1959          2006
# 45      61.000000     7658            9            5       2005          2005
# 1348    69.879741    16196            7            5       1998          1998
# 55     100.000000    10175            6            5       1964          1964
# ...           ...      ...          ...          ...        ...           ...
# 763     82.000000     9430            8            5       1999          1999
# 835     60.000000     9600            4            7       1950          1995
# 1216    68.000000     8930            6            5       1978          1978
# 559     69.879741     3196            7            5       2003          2004
# 684     58.000000    16770            7            5       1998          1998
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 930          0.0          16           0       1450         1466      1466
# 656         54.0         806           0        247         1053      1053
# 45         412.0         456           0       1296         1752      1752
# 1348         0.0        1443           0         39         1482      1494
# 55         272.0         490           0        935         1425      1425
# ...          ...         ...         ...        ...          ...       ...
# 763        673.0        1163           0         89         1252      1268
# 835          0.0         442           0        625         1067      1067
# 1216         0.0           0           0          0            0      1318
# 559         18.0           0           0       1374         1374      1557
# 684         30.0           0           0       1195         1195      1195
#
#       2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# 930          0             0       1466             0             0         2
# 656          0             0       1053             1             0         1
# 45           0             0       1752             1             0         2
# 1348         0             0       1494             1             0         2
# 55           0             0       1425             0             0         2
# ...        ...           ...        ...           ...           ...       ...
# 763       1097             0       2365             1             0         2
# 835          0             0       1067             0             0         2
# 1216       584             0       1902             0             0         2
# 559          0             0       1557             0             0         2
# 684        644             0       1839             0             0         2
#
#       HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 930          0             3             1             7           0
# 656          1             3             1             5           0
# 45           0             2             1             6           1
# 1348         0             3             1             5           1
# 55           0             3             1             7           1
# ...        ...           ...           ...           ...         ...
# 763          1             3             1             8           1
# 835          0             2             1             4           0
# 1216         0             4             2             8           0
# 559          0             2             1             7           1
# 684          1             4             1             7           0
#
#       GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 930        2007.0           3         610         100           18
# 656        1959.0           1         312           0            0
# 45         2005.0           2         576         196           82
# 1348       1998.0           2         514         402           25
# 55         1964.0           2         576           0            0
# ...           ...         ...         ...         ...          ...
# 763        1999.0           3         856           0          128
# 835        1996.0           2         436         290            0
# 1216       1978.0           2         539           0            0
# 559        2003.0           2         420         143           20
# 684        1998.0           2         486           0           81
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold
# 930               0          0            0         0        0       7    2009
# 656               0          0            0         0        0       8    2008
# 45                0          0            0         0        0       2    2010
# 1348              0          0            0         0        0       8    2007
# 55                0        407            0         0        0       7    2008
# ...             ...        ...          ...       ...      ...     ...     ...
# 763               0          0          180         0        0       7    2009
# 835               0          0            0         0        0       2    2010
# 1216              0          0            0         0        0       4    2010
# 559               0          0            0         0        0      10    2006
# 684               0          0            0         0        0       6    2010
#
# [1314 rows x 35 columns]

# %%
# now with this fit, transform both train and test dataset
X_train_scale = pd.DataFrame(scaler.transform(X_train_num.values), columns=X_train_num.columns, index=X_train_num.index)

X_test_scale = pd.DataFrame(scaler.transform(X_test_num.values), columns=X_test_num.columns, index=X_test_num.index)

# %%
X_train_scale.head()
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 930      0.178082  0.035640     0.777778         0.50   0.978261
# 656      0.174658  0.040697     0.444444         0.75   0.630435
# 45       0.136986  0.029718     0.888889         0.50   0.963768
# 1348     0.167396  0.069625     0.666667         0.50   0.913043
# 55       0.270548  0.041483     0.555556         0.50   0.666667
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 930       0.950000     0.00000    0.002835         0.0   0.673479
# 656       0.933333     0.03375    0.142807         0.0   0.114724
# 45        0.916667     0.25750    0.080794         0.0   0.601951
# 1348      0.800000     0.00000    0.255670         0.0   0.018114
# 55        0.233333     0.17000    0.086818         0.0   0.434278
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 930      0.239935  0.259752       0.0           0.0   0.213263      0.000000
# 656      0.172340  0.164984       0.0           0.0   0.135456      0.333333
# 45       0.286743  0.325379       0.0           0.0   0.267144      0.333333
# 1348     0.242553  0.266177       0.0           0.0   0.218538      0.333333
# 55       0.233224  0.250344       0.0           0.0   0.205539      0.000000
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 930            0.0  0.666667       0.0         0.375      0.333333
# 656            0.0  0.333333       0.5         0.375      0.333333
# 45             0.0  0.666667       0.0         0.250      0.333333
# 1348           0.0  0.666667       0.0         0.375      0.333333
# 55             0.0  0.666667       0.0         0.375      0.333333
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# 930       0.416667    0.000000     0.972727        0.75    0.430183
# 656       0.250000    0.000000     0.536364        0.25    0.220028
# 45        0.333333    0.333333     0.954545        0.50    0.406206
# 1348      0.250000    0.333333     0.890909        0.50    0.362482
# 55        0.416667    0.333333     0.581818        0.50    0.406206
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 930     0.116686     0.032907            0.0   0.000000          0.0
# 656     0.000000     0.000000            0.0   0.000000          0.0
# 45      0.228705     0.149909            0.0   0.000000          0.0
# 1348    0.469078     0.045704            0.0   0.000000          0.0
# 55      0.000000     0.000000            0.0   0.801181          0.0
#
#       PoolArea  MiscVal    MoSold  YrSold
# 930        0.0      0.0  0.545455    0.75
# 656        0.0      0.0  0.636364    0.50
# 45         0.0      0.0  0.090909    1.00
# 1348       0.0      0.0  0.636364    0.25
# 55         0.0      0.0  0.545455    0.50

# %% [markdown]
# ## Handling `Temporal variables`
#
# As dicussed in the previous data exploration notebook there are three temporal variables:
# - GarageYrBlt: Year garage was built
# - YearBuilt: Original construction date
# - YearRemodAdd: Remodel date
#
# For these variables, we will capture the difference in time between these variables and the year in which the house was sold

# %%
def years_diff(df, var):
    df["YrSold_-_" + var] = df["YrSold"] - df[var]
    return df

# %%
for var in ["YearBuilt", "YearRemodAdd", "GarageYrBlt"]:
    X_train_diff = years_diff(X_train, var)
    X_test_diff = years_diff(X_test, var)

# %%
print("Original table: ", X_train.loc[0,"YrSold"], X_train.loc[0,"YearBuilt"], X_train.loc[0,"YearRemodAdd"], X_train.loc[0,"GarageYrBlt"])
print("Date difference: ", X_train_diff.loc[0,"YrSold"], X_train_diff.loc[0,"YrSold_-_YearBuilt"], X_train_diff.loc[0,"YrSold_-_YearRemodAdd"], X_train_diff.loc[0,"YrSold_-_GarageYrBlt"])
# Out:
# Original table:  2008 2003 2003 2003.0
# Date difference:  2008 5 5 5.0

# %%
# lets drop "YrSold" from both train and test set
X_train_diff.drop(["YrSold"], axis=1, inplace=True)
X_test_diff.drop(["YrSold"], axis=1, inplace=True)

# %%
X_train_diff.head()
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 930          20       RL    73.000000     8925   Pave  Missing      IR1
# 656          20       RL    72.000000    10007   Pave  Missing      IR1
# 45          120       RL    61.000000     7658   Pave  Missing      Reg
# 1348         20       RL    69.879741    16196   Pave  Missing      IR3
# 55           20       RL   100.000000    10175   Pave  Missing      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 930          HLS    AllPub    Inside       Gtl       Timber       Norm
# 656          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 45           Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 1348         Low    AllPub    Inside       Gtl      SawyerW       Norm
# 55           Lvl    AllPub    Inside       Gtl        NAmes       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 930        Norm     1Fam     1Story            8            5       2007
# 656        Norm     1Fam     1Story            5            7       1959
# 45         Norm   TwnhsE     1Story            9            5       2005
# 1348       Norm     1Fam     1Story            7            5       1998
# 55         Norm     1Fam     1Story            6            5       1964
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 930           2007     Gable  CompShg     VinylSd     VinylSd    Missing
# 656           2006     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 45            2005       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 1348          1998     Gable  CompShg     VinylSd     VinylSd    Missing
# 55            1964     Gable  CompShg     HdBoard     Plywood    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 930          0.0        Gd        TA      PConc       Gd       TA
# 656         54.0        Gd        TA     CBlock       TA       TA
# 45         412.0        Ex        TA      PConc       Ex       TA
# 1348         0.0        Gd        TA      PConc       Gd       TA
# 55         272.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 930            Av          GLQ          16          Unf           0
# 656            No          ALQ         806          Unf           0
# 45             No          GLQ         456          Unf           0
# 1348           Gd          GLQ        1443          Unf           0
# 55             No          BLQ         490          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 930        1450         1466    GasA        Ex          Y      SBrkr
# 656         247         1053    GasA        Ex          Y      SBrkr
# 45         1296         1752    GasA        Ex          Y      SBrkr
# 1348         39         1482    GasA        Ex          Y      SBrkr
# 55          935         1425    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 930       1466         0             0       1466             0             0
# 656       1053         0             0       1053             1             0
# 45        1752         0             0       1752             1             0
# 1348      1494         0             0       1494             1             0
# 55        1425         0             0       1425             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 930          2         0             3             1          Gd
# 656          1         1             3             1          Gd
# 45           2         0             2             1          Ex
# 1348         2         0             3             1          Gd
# 55           2         0             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 930              7        Typ           0     Missing     Attchd       2007.0
# 656              5        Typ           0     Missing     Attchd       1959.0
# 45               6        Typ           1          Gd     Attchd       2005.0
# 1348             5        Typ           1          Fa     Attchd       1998.0
# 55               7        Typ           1          Gd     Attchd       1964.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 930           Fin           3         610         TA         TA          Y
# 656           RFn           1         312         TA         TA          Y
# 45            RFn           2         576         TA         TA          Y
# 1348          RFn           2         514         TA         TA          Y
# 55            RFn           2         576         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 930          100           18              0          0            0
# 656            0            0              0          0            0
# 45           196           82              0          0            0
# 1348         402           25              0          0            0
# 55             0            0              0        407            0
#
#       PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold SaleType  \
# 930          0  Missing  Missing     Missing        0       7       WD
# 656          0  Missing    MnPrv     Missing        0       8       WD
# 45           0  Missing  Missing     Missing        0       2       WD
# 1348         0  Missing  Missing     Missing        0       8       WD
# 55           0  Missing  Missing     Missing        0       7       WD
#
#      SaleCondition  LotFrontage_na  MasVnrArea_na  GarageYrBlt_na  \
# 930         Normal               0              0               0
# 656         Normal               0              0               0
# 45          Normal               0              0               0
# 1348        Normal               1              0               0
# 55          Normal               0              0               0
#
#       log_LotFrontage  log_1stFlrSF  log_GrLivArea  log_LotArea  \
# 930          4.290459      7.290293       7.290293     9.096612
# 656          4.276666      6.959399       6.959399     9.211040
# 45           4.110874      7.468513       7.468513     8.943506
# 1348         4.246776      7.309212       7.309212     9.692520
# 55           4.605170      7.261927       7.261927     9.227689
#
#       binary_ScreenPorch  binary_EnclosedPorch  YrSold_-_YearBuilt  \
# 930                    0                     0                   2
# 656                    0                     0                  49
# 45                     0                     0                   5
# 1348                   0                     0                   9
# 55                     0                     0                  44
#
#       YrSold_-_YearRemodAdd  YrSold_-_GarageYrBlt
# 930                       2                   2.0
# 656                       2                  49.0
# 45                        5                   5.0
# 1348                      9                   9.0
# 55                       44                  44.0

# %% [markdown]
# ## Transforming `Categorical variables`
#
# We will apply order mappings according to order or related quality etc. Please refer data description here -https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data?select=data_description.txt

# %%
# mappings string to numbers based on quality

map_quality = {"Po": 1, "Fa": 2, "TA": 3, "Gd": 4, "Ex": 5, "Missing": 0, "NA": 0}

vars_qual = ["ExterQual", "ExterCond", "BsmtQual", "BsmtCond",
             "HeatingQC", "KitchenQual", "FireplaceQu",
             "GarageQual", "GarageCond",
            ]

for var in vars_qual:
    X_train["map_"+ var] = X_train[var].map(map_quality)
    X_test["map_"+ var] = X_test[var].map(map_quality)

# %%
X_train[["ExterQual", "map_ExterQual","BsmtQual","map_BsmtQual","FireplaceQu","map_FireplaceQu"]].head()
# Out:
#      ExterQual  map_ExterQual BsmtQual  map_BsmtQual FireplaceQu  \
# 930         Gd              4       Gd             4     Missing
# 656         Gd              4       TA             3     Missing
# 45          Ex              5       Ex             5          Gd
# 1348        Gd              4       Gd             4          Fa
# 55          TA              3       TA             3          Gd
#
#       map_FireplaceQu
# 930                 0
# 656                 0
# 45                  4
# 1348                2
# 55                  4

# %%
map_exposure = {'No': 1, 'Mn': 2, 'Av': 3, 'Gd': 4}

var_expose = 'BsmtExposure'

X_train["map_"+ var_expose] = X_train[var_expose].map(map_exposure)
X_test["map_"+ var_expose] = X_test[var_expose].map(map_exposure)

# %%
map_finish = {'Missing': 0, 'NA': 0, 'Unf': 1, 'LwQ': 2, 'Rec': 3, 'BLQ': 4, 'ALQ': 5, 'GLQ': 6}

vars_finish = ['BsmtFinType1', 'BsmtFinType2']

for var in vars_finish:
    X_train["map_"+ var] = X_train[var].map(map_finish)
    X_test["map_"+ var] = X_test[var].map(map_finish)

# %%
map_garage = {'Missing': 0, 'NA': 0, 'Unf': 1, 'RFn': 2, 'Fin': 3}

var_garage = 'GarageFinish'

X_train["map_"+ var_garage] = X_train[var_garage].map(map_garage )
X_test["map_"+ var_garage] = X_test[var_garage].map(map_garage )

# %%
map_fence = {'Missing': 0, 'NA': 0, 'MnWw': 1, 'GdWo': 2, 'MnPrv': 3, 'GdPrv': 4}

var_fence = 'Fence'

X_train["map_"+ var_fence] = X_train[var_fence].map(map_fence)
X_test["map_"+ var_fence] = X_test[var_fence].map(map_fence)

# %% [markdown]
# ### Identify rarelabels for rest of the categorical variables`
#
# All values of categorical variables that are shared by less than 1% of houses, well be replaced by the string "Rare".

# %%
# make a list of all catergorical

vars_qual_all  = vars_qual + [var_expose] + vars_finish + [var_garage] + [var_fence]

#rest of the variales
cat_others = [ var for var in vars_cat if var not in vars_qual_all ]

len(cat_others)
# Out:
# 30

# %%
# this function will find rare labels
def find_rare_labels(df, var, perc):

    df_copy = df.copy()

    # find the counts per catergorical value
    tmp_cat = df.groupby(var)[var].count() / len(df)

    # return categories that very rare
    return tmp_cat[tmp_cat < perc].index

# %%
for var in cat_others:

    # find the rare labels list
    rare_arr = find_rare_labels(X_train, var, 0.01)

    print(var, rare_arr)
    print()

    # replace rare categories by the string "Rare"
    X_train["rare_" + var] = np.where(X_train[var].isin(
        rare_arr), 'Rare', X_train[var])

    #remember to use the same for the test set
    X_test["rare_" + var] = np.where(X_test[var].isin(
        rare_arr), 'Rare', X_test[var])
# Out:
# MSZoning Index(['C (all)'], dtype='object', name='MSZoning')
#
# Street Index(['Grvl'], dtype='object', name='Street')
#
# Alley Index([], dtype='object', name='Alley')
#
# LotShape Index(['IR3'], dtype='object', name='LotShape')
#
# LandContour Index([], dtype='object', name='LandContour')
#
# Utilities Index(['NoSeWa'], dtype='object', name='Utilities')
#
# LotConfig Index(['FR3'], dtype='object', name='LotConfig')
#
# LandSlope Index(['Sev'], dtype='object', name='LandSlope')
#
# Neighborhood Index(['Blueste', 'NPkVill', 'Veenker'], dtype='object', name='Neighborhood')
#
# Condition1 Index(['PosA', 'RRAe', 'RRNe', 'RRNn'], dtype='object', name='Condition1')
#
# Condition2 Index(['Artery', 'Feedr', 'PosA', 'PosN', 'RRAe', 'RRNn'], dtype='object', name='Condition2')
#
# BldgType Index([], dtype='object', name='BldgType')
#
# HouseStyle Index(['1.5Unf', '2.5Fin', '2.5Unf'], dtype='object', name='HouseStyle')
#
# RoofStyle Index(['Flat', 'Gambrel', 'Mansard', 'Shed'], dtype='object', name='RoofStyle')
#
# RoofMatl Index(['ClyTile', 'Membran', 'Metal', 'Roll', 'Tar&Grv', 'WdShake', 'WdShngl'], dtype='object', name='RoofMatl')
#
# Exterior1st Index(['AsphShn', 'BrkComm', 'CBlock', 'ImStucc', 'Stone'], dtype='object', name='Exterior1st')
#
# Exterior2nd Index(['AsphShn', 'Brk Cmn', 'CBlock', 'ImStucc', 'Other', 'Stone'], dtype='object', name='Exterior2nd')
#
# MasVnrType Index(['BrkCmn'], dtype='object', name='MasVnrType')
#
# Foundation Index(['Stone', 'Wood'], dtype='object', name='Foundation')
#
# Heating Index(['Floor', 'Grav', 'OthW', 'Wall'], dtype='object', name='Heating')
#
# CentralAir Index([], dtype='object', name='CentralAir')
#
# Electrical Index(['FuseP', 'Mix'], dtype='object', name='Electrical')
#
# Functional Index(['Maj1', 'Maj2', 'Sev'], dtype='object', name='Functional')
#
# GarageType Index(['2Types', 'CarPort'], dtype='object', name='GarageType')
#
# PavedDrive Index([], dtype='object', name='PavedDrive')
#
# PoolQC Index(['Ex', 'Fa', 'Gd'], dtype='object', name='PoolQC')
#
# MiscFeature Index(['Gar2', 'Othr', 'TenC'], dtype='object', name='MiscFeature')
#
# SaleType Index(['CWD', 'Con', 'ConLD', 'ConLI', 'ConLw', 'Oth'], dtype='object', name='SaleType')
#
# SaleCondition Index(['AdjLand', 'Alloca'], dtype='object', name='SaleCondition')
#
# MSSubClass Index([40, 45, 180], dtype='int64', name='MSSubClass')
# /tmp/ipython-input-3548355215.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["rare_" + var] = np.where(X_train[var].isin(
# /tmp/ipython-input-3548355215.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["rare_" + var] = np.where(X_test[var].isin(
# /tmp/ipython-input-3548355215.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["rare_" + var] = np.where(X_train[var].isin(
# /tmp/ipython-input-3548355215.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["rare_" + var] = np.where(X_test[var].isin(

# %%
rare_cat_others = [col for col in X_train if col.startswith("rare_")]
X_train[rare_cat_others].head()
# Out:
#      rare_MSZoning rare_Street rare_Alley rare_LotShape rare_LandContour  \
# 930             RL        Pave    Missing           IR1              HLS
# 656             RL        Pave    Missing           IR1              Lvl
# 45              RL        Pave    Missing           Reg              Lvl
# 1348            RL        Pave    Missing          Rare              Low
# 55              RL        Pave    Missing           IR1              Lvl
#
#      rare_Utilities rare_LotConfig rare_LandSlope rare_Neighborhood  \
# 930          AllPub         Inside            Gtl            Timber
# 656          AllPub         Inside            Gtl             NAmes
# 45           AllPub         Inside            Gtl           NridgHt
# 1348         AllPub         Inside            Gtl           SawyerW
# 55           AllPub         Inside            Gtl             NAmes
#
#      rare_Condition1 rare_Condition2 rare_BldgType rare_HouseStyle  \
# 930             Norm            Norm          1Fam          1Story
# 656             Norm            Norm          1Fam          1Story
# 45              Norm            Norm        TwnhsE          1Story
# 1348            Norm            Norm          1Fam          1Story
# 55              Norm            Norm          1Fam          1Story
#
#      rare_RoofStyle rare_RoofMatl rare_Exterior1st rare_Exterior2nd  \
# 930           Gable       CompShg          VinylSd          VinylSd
# 656           Gable       CompShg          HdBoard          HdBoard
# 45              Hip       CompShg          MetalSd          MetalSd
# 1348          Gable       CompShg          VinylSd          VinylSd
# 55            Gable       CompShg          HdBoard          Plywood
#
#      rare_MasVnrType rare_Foundation rare_Heating rare_CentralAir  \
# 930          Missing           PConc         GasA               Y
# 656          BrkFace          CBlock         GasA               Y
# 45           BrkFace           PConc         GasA               Y
# 1348         Missing           PConc         GasA               Y
# 55           BrkFace          CBlock         GasA               Y
#
#      rare_Electrical rare_Functional rare_GarageType rare_PavedDrive  \
# 930            SBrkr             Typ          Attchd               Y
# 656            SBrkr             Typ          Attchd               Y
# 45             SBrkr             Typ          Attchd               Y
# 1348           SBrkr             Typ          Attchd               Y
# 55             SBrkr             Typ          Attchd               Y
#
#      rare_PoolQC rare_MiscFeature rare_SaleType rare_SaleCondition  \
# 930      Missing          Missing            WD             Normal
# 656      Missing          Missing            WD             Normal
# 45       Missing          Missing            WD             Normal
# 1348     Missing          Missing            WD             Normal
# 55       Missing          Missing            WD             Normal
#
#      rare_MSSubClass
# 930               20
# 656               20
# 45               120
# 1348              20
# 55                20

# %% [markdown]
# ### Encoding Categorical variables
#
# Here, we will transform the strings values in to numbers. Here, we will keep it simple, we will capture the relationship between the label and the target
#
# In Chapter 8, we will have a comprehensive learning and handson eeperince with various categorical encoding techniques

# %%
# function to assign integers to catergories order by mean salePrice low to high

def impute_category(X_train, X_test, y_train, var, target):

    df_tmp = pd.concat([X_train, y_train], axis=1)

    #create the list of catgorical values for a variable sorted by the mean Sale Price less to high
    category_order = df_tmp.groupby([var])[target].mean().sort_values().index

    # create mapping for each category value to an integer in increasing order
    ordered_num_labels = {k: i for i, k in enumerate(category_order)}

    #e.g.: {k: i for i, k in enumerate(['a','b','c','d'])}
    # {'a': 0, 'b': 1, 'c': 2, 'd': 3}

    print(var, ordered_num_labels)
    print()

    # use the mapping asbe to replace categories
    X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
    X_test["encode_" + var] = X_test[var].map(ordered_num_labels)

# %%
for var in cat_others:
    impute_category(X_train, X_test, y_train, var, 'SalePrice')
# Out:
# MSZoning {'C (all)': 0, 'RM': 1, 'RH': 2, 'RL': 3, 'FV': 4}
#
# Street {'Grvl': 0, 'Pave': 1}
#
# Alley {'Grvl': 0, 'Pave': 1, 'Missing': 2}
#
# LotShape {'Reg': 0, 'IR1': 1, 'IR3': 2, 'IR2': 3}
#
# LandContour {'Bnk': 0, 'Lvl': 1, 'Low': 2, 'HLS': 3}
#
# Utilities {'NoSeWa': 0, 'AllPub': 1}
#
# LotConfig {'FR2': 0, 'Inside': 1, 'Corner': 2, 'FR3': 3, 'CulDSac': 4}
#
# LandSlope {'Gtl': 0, 'Mod': 1, 'Sev': 2}
#
# Neighborhood {'IDOTRR': 0, 'MeadowV': 1, 'BrDale': 2, 'Edwards': 3, 'BrkSide': 4, 'OldTown': 5, 'Sawyer': 6, 'Blueste': 7, 'NPkVill': 8, 'SWISU': 9, 'NAmes': 10, 'Mitchel': 11, 'SawyerW': 12, 'NWAmes': 13, 'Gilbert': 14, 'Blmngtn': 15, 'CollgCr': 16, 'ClearCr': 17, 'Crawfor': 18, 'Somerst': 19, 'Veenker': 20, 'Timber': 21, 'StoneBr': 22, 'NridgHt': 23, 'NoRidge': 24}
#
# Condition1 {'Artery': 0, 'RRAe': 1, 'Feedr': 2, 'RRAn': 3, 'Norm': 4, 'RRNe': 5, 'PosN': 6, 'PosA': 7, 'RRNn': 8}
#
# Condition2 {'RRNn': 0, 'Artery': 1, 'Feedr': 2, 'Norm': 3, 'RRAe': 4, 'PosN': 5, 'PosA': 6}
#
# BldgType {'2fmCon': 0, 'Duplex': 1, 'Twnhs': 2, 'TwnhsE': 3, '1Fam': 4}
#
# HouseStyle {'1.5Unf': 0, 'SFoyer': 1, '1.5Fin': 2, '2.5Unf': 3, 'SLvl': 4, '1Story': 5, '2Story': 6, '2.5Fin': 7}
#
# RoofStyle {'Gambrel': 0, 'Gable': 1, 'Mansard': 2, 'Flat': 3, 'Hip': 4, 'Shed': 5}
#
# RoofMatl {'Roll': 0, 'ClyTile': 1, 'CompShg': 2, 'Metal': 3, 'Tar&Grv': 4, 'WdShake': 5, 'Membran': 6, 'WdShngl': 7}
#
# Exterior1st {'BrkComm': 0, 'AsphShn': 1, 'CBlock': 2, 'AsbShng': 3, 'Wd Sdng': 4, 'MetalSd': 5, 'WdShing': 6, 'HdBoard': 7, 'Stucco': 8, 'Plywood': 9, 'BrkFace': 10, 'VinylSd': 11, 'CemntBd': 12, 'Stone': 13, 'ImStucc': 14}
#
# Exterior2nd {'CBlock': 0, 'AsbShng': 1, 'Brk Cmn': 2, 'AsphShn': 3, 'Stone': 4, 'Wd Sdng': 5, 'MetalSd': 6, 'Stucco': 7, 'Wd Shng': 8, 'HdBoard': 9, 'Plywood': 10, 'BrkFace': 11, 'ImStucc': 12, 'VinylSd': 13, 'CmentBd': 14, 'Other': 15}
#
# MasVnrType {'BrkCmn': 0, 'Missing': 1, 'BrkFace': 2, 'Stone': 3}
#
# Foundation {'Slab': 0, 'BrkTil': 1, 'CBlock': 2, 'Stone': 3, 'Wood': 4, 'PConc': 5}
#
# Heating {'Floor': 0, 'Grav': 1, 'Wall': 2, 'OthW': 3, 'GasW': 4, 'GasA': 5}
#
# CentralAir {'N': 0, 'Y': 1}
#
# Electrical {'Mix': 0, 'FuseP': 1, 'FuseF': 2, 'FuseA': 3, 'SBrkr': 4}
#
# Functional {'Maj2': 0, 'Sev': 1, 'Maj1': 2, 'Min2': 3, 'Min1': 4, 'Mod': 5, 'Typ': 6}
#
# GarageType {'CarPort': 0, 'Detchd': 1, '2Types': 2, 'Basment': 3, 'Attchd': 4, 'BuiltIn': 5}
#
# PavedDrive {'N': 0, 'P': 1, 'Y': 2}
#
# PoolQC {'Missing': 0, 'Gd': 1, 'Fa': 2, 'Ex': 3}
#
# MiscFeature {'Othr': 0, 'Shed': 1, 'Gar2': 2, 'Missing': 3, 'TenC': 4}
#
# SaleType {'Oth': 0, 'ConLD': 1, 'COD': 2, 'ConLw': 3, 'WD': 4, 'ConLI': 5, 'CWD': 6, 'Con': 7, 'New': 8}
#
# SaleCondition {'AdjLand': 0, 'Abnorml': 1, 'Family': 2, 'Alloca': 3, 'Normal': 4, 'Partial': 5}
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)
# MSSubClass {30: 0, 180: 1, 45: 2, 190: 3, 90: 4, 160: 5, 50: 6, 85: 7, 70: 8, 80: 9, 40: 10, 20: 11, 75: 12, 120: 13, 60: 14}
# /tmp/ipython-input-791370499.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_train["encode_"+ var] = X_train[var].map(ordered_num_labels)
# /tmp/ipython-input-791370499.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test["encode_" + var] = X_test[var].map(ordered_num_labels)

# %%
# check for null values in train set
[var for var in X_train.columns if X_train[var].isnull().sum() > 0]
# Out:
# []

# %%
# check for null values in test  set
[var for var in X_test.columns if X_test[var].isnull().sum() > 0]
# Out:
# ['encode_Condition2']

# %%
df_tmp = pd.concat([X_train.filter(regex='^encode_'), np.log(y_train)], axis=1)
df_tmp.head()
# Out:
#       encode_MSZoning  encode_Street  encode_Alley  encode_LotShape  \
# 930                 3              1             2                1
# 656                 3              1             2                1
# 45                  3              1             2                0
# 1348                3              1             2                2
# 55                  3              1             2                1
#
#       encode_LandContour  encode_Utilities  encode_LotConfig  \
# 930                    3                 1                 1
# 656                    1                 1                 1
# 45                     1                 1                 1
# 1348                   2                 1                 1
# 55                     1                 1                 1
#
#       encode_LandSlope  encode_Neighborhood  encode_Condition1  \
# 930                  0                   21                  4
# 656                  0                   10                  4
# 45                   0                   23                  4
# 1348                 0                   12                  4
# 55                   0                   10                  4
#
#       encode_Condition2  encode_BldgType  encode_HouseStyle  encode_RoofStyle  \
# 930                   3                4                  5                 1
# 656                   3                4                  5                 1
# 45                    3                3                  5                 4
# 1348                  3                4                  5                 1
# 55                    3                4                  5                 1
#
#       encode_RoofMatl  encode_Exterior1st  encode_Exterior2nd  \
# 930                 2                  11                  13
# 656                 2                   7                   9
# 45                  2                   5                   6
# 1348                2                  11                  13
# 55                  2                   7                  10
#
#       encode_MasVnrType  encode_Foundation  encode_Heating  encode_CentralAir  \
# 930                   1                  5               5                  1
# 656                   2                  2               5                  1
# 45                    2                  5               5                  1
# 1348                  1                  5               5                  1
# 55                    2                  2               5                  1
#
#       encode_Electrical  encode_Functional  encode_GarageType  \
# 930                   4                  6                  4
# 656                   4                  6                  4
# 45                    4                  6                  4
# 1348                  4                  6                  4
# 55                    4                  6                  4
#
#       encode_PavedDrive  encode_PoolQC  encode_MiscFeature  encode_SaleType  \
# 930                   2              0                   3                4
# 656                   2              0                   3                4
# 45                    2              0                   3                4
# 1348                  2              0                   3                4
# 55                    2              0                   3                4
#
#       encode_SaleCondition  encode_MSSubClass  SalePrice
# 930                      4                 11  12.211060
# 656                      4                 11  11.887931
# 45                       4                 13  12.675764
# 1348                     4                 11  12.278393
# 55                       4                 11  12.103486

# %%
#there are 30 variables in the list that have been encoded
import seaborn as sns

for i in range (0, len(cat_others),5):
    g = sns.pairplot(df_tmp, y_vars=["SalePrice"], x_vars=["encode_"+ cat_others[i],"encode_"+ cat_others[i+1],"encode_"+ cat_others[i+2],"encode_"+ cat_others[i+3],"encode_"+ cat_others[i+4]])

# %%
# Lets analyse relationship betwwen these variables and the target

def plot_cat_vars(X_train, y_train, var):

    #this function will plot mean sale price for each category of the variable

    df_tmp = pd.concat([X_train, np.log(y_train)], axis=1)

    df_tmp.groupby("encode_"+ var)["SalePrice"].mean().plot.bar(color = "grey")
    plt.title("encode_" + var)
    plt.ylabel("SalePrice")
    plt.show()

for var in cat_others:
     plot_cat_vars(X_train, y_train, var)

# %%
for var in cat_others[:3]:
     plot_cat_vars(X_train, y_train, var)

# %% [markdown]
# Here, we can a see monotonic relationship between the variable and the target mean price, higher integer represents higher sale price and lower integer represents lower sale Price

# %% [markdown]
# Thank you for getting to the end of this notebook. Hopefully this notebook has given a very hands on experince with different feature engineering techniques on different
# types of attributes
